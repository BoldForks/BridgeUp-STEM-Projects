# %% [markdown]
# # Unit Challenge #5

# %% [markdown]
# Python and pandas can help us in the world of data science, but also in everyday life.
#
# Let's use pandas to keep track of our grades in school!

# %%
#Read in the gradebook.csv file which contains a list of a typical high school student's courses and grades.
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/gradebook.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Display the entire dataframe.
display(df)
# Out:
#            Term             Subject              Course  Grade Participation
# 0     Fall 2020                 ELA             English   82.0             G
# 1     Fall 2020      Social Studies      Global History   89.0             G
# 2     Fall 2020                Math            Geometry   89.0             N
# 3     Fall 2020             Science       Earth Science   93.0             E
# 4     Fall 2020             Science              Health   98.0             N
# 5     Fall 2020    Foreign Language             Spanish   82.0             S
# 6     Fall 2020         Art & Music      Graphic Design   96.0             E
# 7   Spring 2021                 ELA             English   75.0             G
# 8   Spring 2021      Social Studies      Global History   99.0             S
# 9   Spring 2021                Math            Geometry   80.0             G
# 10  Spring 2021             Science       Earth Science   76.0             E
# ...

# %% [markdown]
# You might notice that the last set of grades for the Spring 2024 Term display `NaN` values. `NaN` stands for "Not a Number" and it occurs when there is no value in that specific location on the row.
#
# The student whom these grades belong to is in their last semester of high school!
# They have the following courses in Spring 2024.
# * English
# * Economics
# * Calculus
# * Physics
# * Lacrosse
#
# Create a list of the subjects listed above and add them to the dataframe as well as a list of the subjects that they are associated with.

# %%
#Create list of courses
courses = ["English", "Economics", "Calculus", "Physics", "Lacrosse"]

#Create list of subjects
subjects = ["ELA", "Social Studies", "Math", "Science", "Physical Education"]

#Add them to the dataframe. (A for loop and the range() function may come in handy)
for i in df:
  if "Nan":
    
df["Courses"] = courses
df["Subjects"] = subjects
# Out:
#   File "<ipython-input-8-f84fd7938ad3>", line 11
#     df["Courses"] = courses
#                            ^
# IndentationError: expected an indented block

# %% [markdown]
# The student has had a major case of senioritis and is concerned about keeping a minimum 90 average in each subject area.
# Find the student's current average grade.

# %%
#Find student's average overall grade.

# %% [markdown]
# Then, create a function that finds and prints the student's average in each subject area using the .loc attribute. The function should return a dataframe consisting of only values from the specified subject area.

# %%
#Subject area average function

# %%
#Don't forget to call the function!

# %% [markdown]
# Looks like the student has some work to do!
#
# Create a function, `gradePredictor`, that takes as a parameter a grade value for a missing course grade and returns the average that would result if the student actually receives that grade.
#
# (Hint: You may need more parameters than the one specified above^)

# %% [markdown]
# Now call the function and see what is needed to get a 90 or above!

# %% [markdown]
# ## Bonus
#
# You can try using this with your own grades now! You can try using this with your own grades now by opening and changing the values in the `gradebook.csv` file!
